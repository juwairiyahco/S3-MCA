# %% [markdown]
# instead of neighbors use tree modules

# %%
import pandas as pd
from sklearn import datasets
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
iris=datasets.load_iris()
X,y=iris.data,iris.target
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,random_state=78) 
dt=tree.DecisionTreeClassifier()
dt.fit(X_train,y_train)
y_pred=dt.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9111111111111111

# %%
tree.plot_tree(dt)
# Out:
# [Text(0.5, 0.9, 'x[2] <= 2.45\ngini = 0.664\nsamples = 105\nvalue = [39, 31, 35]'),
#  Text(0.375, 0.7, 'gini = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.625, 0.7, 'x[3] <= 1.75\ngini = 0.498\nsamples = 66\nvalue = [0, 31, 35]'),
#  Text(0.5, 0.5, 'x[2] <= 4.95\ngini = 0.202\nsamples = 35\nvalue = [0, 31, 4]'),
#  Text(0.25, 0.3, 'x[0] <= 4.95\ngini = 0.062\nsamples = 31\nvalue = [0, 30, 1]'),
#  Text(0.125, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.375, 0.1, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]'),
#  Text(0.75, 0.3, 'x[0] <= 6.5\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.625, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.875, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.75, 0.5, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]')]

# %%
print(iris.target_names[dt.predict([[3,4,5,6]])])
# Out:
# ['virginica']
